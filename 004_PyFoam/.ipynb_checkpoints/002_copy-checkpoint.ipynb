# %% [markdown]
# # チュートリアルからクローン

# %% [markdown]
# 必要なライブラリをインポート

# %%
from os import getcwd, path
import os
import shutil
from PyFoam.RunDictionary.SolutionDirectory import SolutionDirectory

# %% [markdown]
# ## PyFoamライブラリを使用する方法

# %% [markdown]
# SolutionDirectoryのcloneCase関数を使った例を示します。

# %%
# コピー元のケースディレクトリ
source_case = "pimpleFoam"

# コピー先のファイル名
fileName = "pimpleFoam_cloneCase"

# 現在の作業ディレクトリを取得し、そこにコピー
destination_path = path.join(getcwd(), fileName)

# SolutionDirectoryを使用してケースをコピー
template = SolutionDirectory(source_case).cloneCase(destination_path)

template

# %%
template.name
# Out:
# '/home/kamakiri/OpenFOAM/kamakiri-v2406/run/17_gijyutusyo/004_PyFoam/pimpleFoam_cloneCase'

# %%
template.clearResults
# Out:
# <bound method SolutionDirectory.clearResults of <PyFoam.RunDictionary.SolutionDirectory.SolutionDirectory object at 0x7fac481d9420>>

# %% [markdown]
# その他にもさまざまな関数が用意されている

# %% [markdown]
# ## Pythonの標準ライブラリを使用する方法

# %%
# コピーする関数
def copy_tutorial_case(source_case, destination):
    # shutilを使用してディレクトリをコピー
    shutil.copytree(source_case, destination)

# %%
# コピー元のケースディレクトリ
source_case = "pimpleFoam"

fileName = "pimpleFoam_copy"

copy_tutorial_case(source_case, fileName)

# %% [markdown]
# # 計算を実行

# %%
from PyFoam.Execution.BasicRunner import BasicRunner

# %%
# ケースディレクトリの指定
case_dir = "pimpleFoam_run"

template.cloneCase(path.join(getcwd(), case_dir))

# %%
# blockMeshの実行
block_mesh_runner = BasicRunner(argv=["blockMesh", "-case", case_dir])
block_mesh_runner.start()

# pimpleFoamの実行
pimpleFoam_runner = BasicRunner(argv=["pimpleFoam", "-case", case_dir])
pimpleFoam_runner.start()
# Out:
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  v2012                                 |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _7bdb509494-20201222 OPENFOAM=2012
# Arch   : "LSB;label=32;scalar=64"
# Exec   : blockMesh -case pitzDaily_run
# Date   : Oct 15 2024
# Time   : 14:14:56
# Host   : JPN118658-M
# PID    : 4738
# I/O    : uncollated
# Case   : /mnt/c/work/OpenFOAM/20240906_gijyutusyo/003_PyFoam/pitzDaily_run
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Creating block mesh from "system/blockMeshDict"
# Creating block edges
# No non-planar block faces defined
# Creating topology blocks
# Creating topology patches
#
# Creating block mesh topology
#
# Check topology
#
# 	Basic statistics
# 		Number of internal faces : 5
# 		Number of boundary faces : 20
# 		Number of defined boundary faces : 20
# 		Number of undefined boundary faces : 0
# 	Checking patch -> block consistency
#
# Creating block offsets
# Creating merge list (topological search)...
#
# Creating polyMesh from blockMesh
# Creating patches
# Creating cells
# Creating points with scale 0.001
#     Block 0 cell size :
#         i : 0.00158284 .. 0.000791418
#         j : 0.000318841 .. 0.000420268
#         k : 0.001 .. 0.001
#
#     Block 1 cell size :
#         i : 0.000528387 .. 0.00211355
#         j : 0.00112889 .. 0.000360188
#         k : 0.001 .. 0.001
#
#     Block 2 cell size :
#         i : 0.000528387 .. 0.00211355
#         j : 0.000318841 .. 0.000420268
#         k : 0.001 .. 0.001
#
#     Block 3 cell size :
#         i : 0.0020578 .. 0.00514451
#         j : 0.000940741 .. 0.000940741
#         k : 0.001 .. 0.001
#
#     Block 4 cell size :
#         i : 0.0020466 .. 0.00511651
#         j : 0.00112889 .. 0.000257962
#         k : 0.001 .. 0.001
#
#
# There are no merge patch pairs
#
# Writing polyMesh with 0 cellZones
# ----------------
# Mesh Information
# ----------------
#   boundingBox: (-0.0206 -0.0254 -0.0005) (0.29 0.0254 0.0005)
#   nPoints: 25012
#   nCells: 12225
#   nFaces: 49180
#   nInternalFaces: 24170
# ----------------
# Patches
# ----------------
#   patch 0 (start: 24170 size: 30) name: inlet
#   patch 1 (start: 24200 size: 57) name: outlet
#   patch 2 (start: 24257 size: 223) name: upperWall
#   patch 3 (start: 24480 size: 250) name: lowerWall
#   patch 4 (start: 24730 size: 24450) name: frontAndBack
#
# End
#
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  v2012                                 |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _7bdb509494-20201222 OPENFOAM=2012
# Arch   : "LSB;label=32;scalar=64"
# Exec   : pimpleFoam -case pitzDaily_run
# Date   : Oct 15 2024
# Time   : 14:14:56
# Host   : JPN118658-M
# PID    : 4743
# I/O    : uncollated
# Case   : /mnt/c/work/OpenFOAM/20240906_gijyutusyo/003_PyFoam/pitzDaily_run
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0
#
#
# PIMPLE: Operating solver in PISO mode
#
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
# No MRF models present
#
# No finite volume options present
# Courant Number mean: 0.000874894 max: 0.315889
#
# Starting time loop
#
# Courant Number mean: 0.000874894 max: 0.315889
# deltaT = 0.000120482
# Time = 0.000120482
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 1, Final residual = 3.10952e-06, No Iterations 6
# smoothSolver:  Solving for Uy, Initial residual = 1, Final residual = 3.3068e-06, No Iterations 7
# GAMG:  Solving for p, Initial residual = 1, Final residual = 0.00882394, No Iterations 13
# time step continuity errors : sum local = 1.86024e-05, global = 4.43739e-06, cumulative = 4.43739e-06
# GAMG:  Solving for p, Initial residual = 0.0227752, Final residual = 8.28122e-08, No Iterations 24
# time step continuity errors : sum local = 1.78583e-08, global = 1.75293e-09, cumulative = 4.43914e-06
# smoothSolver:  Solving for epsilon, Initial residual = 0.0748323, Final residual = 8.9962e-06, No Iterations 7
# smoothSolver:  Solving for k, Initial residual = 1, Final residual = 9.74025e-06, No Iterations 12
# ExecutionTime = 0.17 s  ClockTime = 0 s
#
# Courant Number mean: 0.513875 max: 9.28229
# deltaT = 6.49968e-05
# Time = 0.000185479
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.731835, Final residual = 8.35719e-06, No Iterations 13
# smoothSolver:  Solving for Uy, Initial residual = 0.15515, Final residual = 7.04659e-06, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.036607, Final residual = 0.000315214, No Iterations 11
# time step continuity errors : sum local = 1.64049e-05, global = -3.79159e-06, cumulative = 6.47557e-07
# GAMG:  Solving for p, Initial residual = 0.0811872, Final residual = 5.97299e-08, No Iterations 24
# time step continuity errors : sum local = 1.26362e-09, global = -7.11532e-11, cumulative = 6.47486e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.0606514, Final residual = 9.43069e-06, No Iterations 13
# smoothSolver:  Solving for k, Initial residual = 0.227374, Final residual = 8.89608e-06, No Iterations 22
# ExecutionTime = 0.25 s  ClockTime = 1 s
#
# Courant Number mean: 0.276586 max: 4.78183
# deltaT = 6.81564e-05
# Time = 0.000253635
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.0201276, Final residual = 7.15583e-06, No Iterations 14
# smoothSolver:  Solving for Uy, Initial residual = 0.0837308, Final residual = 8.84079e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.820419, Final residual = 0.00426814, No Iterations 5
# time step continuity errors : sum local = 8.51295e-06, global = -2.56459e-07, cumulative = 3.91027e-07
# GAMG:  Solving for p, Initial residual = 0.520099, Final residual = 5.89616e-08, No Iterations 23
# time step continuity errors : sum local = 7.39758e-11, global = -4.12688e-12, cumulative = 3.91023e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.0544679, Final residual = 9.66011e-06, No Iterations 16
# smoothSolver:  Solving for k, Initial residual = 0.0681498, Final residual = 8.79875e-06, No Iterations 16
# ExecutionTime = 0.31 s  ClockTime = 1 s
#
# Courant Number mean: 0.290069 max: 3.72172
# deltaT = 7.73521e-05
# Time = 0.000330987
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.0134195, Final residual = 7.10435e-06, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.0182329, Final residual = 5.87672e-06, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.419088, Final residual = 0.00282738, No Iterations 5
# time step continuity errors : sum local = 3.36987e-06, global = 1.19707e-07, cumulative = 5.1073e-07
# GAMG:  Solving for p, Initial residual = 0.293315, Final residual = 7.98242e-08, No Iterations 20
# time step continuity errors : sum local = 5.95649e-11, global = -1.3033e-11, cumulative = 5.10717e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.025661, Final residual = 9.98256e-06, No Iterations 8
# smoothSolver:  Solving for k, Initial residual = 0.0427204, Final residual = 6.57906e-06, No Iterations 12
# ExecutionTime = 0.37 s  ClockTime = 1 s
#
# Courant Number mean: 0.329194 max: 3.9771
# deltaT = 8.71082e-05
# Time = 0.000418095
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00709664, Final residual = 6.24282e-06, No Iterations 6
# smoothSolver:  Solving for Uy, Initial residual = 0.00627273, Final residual = 9.18753e-06, No Iterations 5
# GAMG:  Solving for p, Initial residual = 0.295043, Final residual = 0.00203065, No Iterations 4
# time step continuity errors : sum local = 1.46424e-06, global = -1.64519e-07, cumulative = 3.46198e-07
# GAMG:  Solving for p, Initial residual = 0.138044, Final residual = 6.77737e-08, No Iterations 22
# time step continuity errors : sum local = 4.48525e-11, global = 1.17579e-11, cumulative = 3.46209e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.0271569, Final residual = 7.71316e-06, No Iterations 8
# smoothSolver:  Solving for k, Initial residual = 0.0370117, Final residual = 5.76693e-06, No Iterations 11
# ExecutionTime = 0.42 s  ClockTime = 1 s
#
# Courant Number mean: 0.370764 max: 4.33683
# deltaT = 9.67869e-05
# Time = 0.000514882
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00741754, Final residual = 9.9092e-06, No Iterations 6
# smoothSolver:  Solving for Uy, Initial residual = 0.0071878, Final residual = 9.78842e-06, No Iterations 7
# GAMG:  Solving for p, Initial residual = 0.188527, Final residual = 0.00115192, No Iterations 4
# time step continuity errors : sum local = 8.47694e-07, global = 6.82515e-08, cumulative = 4.14461e-07
# GAMG:  Solving for p, Initial residual = 0.0669639, Final residual = 6.6407e-08, No Iterations 22
# time step continuity errors : sum local = 4.51065e-11, global = -1.14092e-11, cumulative = 4.1445e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.0236256, Final residual = 7.73759e-06, No Iterations 8
# smoothSolver:  Solving for k, Initial residual = 0.0340253, Final residual = 7.97077e-06, No Iterations 10
# ExecutionTime = 0.48 s  ClockTime = 1 s
#
# Courant Number mean: 0.412062 max: 4.66493
# deltaT = 0.000104232
# Time = 0.000619114
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00700453, Final residual = 7.24439e-06, No Iterations 6
# smoothSolver:  Solving for Uy, Initial residual = 0.00730548, Final residual = 6.18865e-06, No Iterations 7
# GAMG:  Solving for p, Initial residual = 0.149135, Final residual = 0.00130304, No Iterations 3
# time step continuity errors : sum local = 9.37516e-07, global = -1.24765e-08, cumulative = 4.01973e-07
# GAMG:  Solving for p, Initial residual = 0.0586647, Final residual = 6.38111e-08, No Iterations 18
# time step continuity errors : sum local = 4.41021e-11, global = -4.87877e-12, cumulative = 4.01968e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.0200422, Final residual = 5.55333e-06, No Iterations 8
# smoothSolver:  Solving for k, Initial residual = 0.0310215, Final residual = 4.84001e-06, No Iterations 10
# ExecutionTime = 0.53 s  ClockTime = 1 s
#
# Courant Number mean: 0.443898 max: 4.89957
# deltaT = 0.000106601
# Time = 0.000725715
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00706351, Final residual = 7.79868e-06, No Iterations 6
# smoothSolver:  Solving for Uy, Initial residual = 0.00749587, Final residual = 5.81685e-06, No Iterations 7
# GAMG:  Solving for p, Initial residual = 0.144739, Final residual = 0.000881786, No Iterations 4
# time step continuity errors : sum local = 6.32521e-07, global = 2.14145e-08, cumulative = 4.23383e-07
# GAMG:  Solving for p, Initial residual = 0.0631237, Final residual = 8.40757e-08, No Iterations 19
# time step continuity errors : sum local = 5.86113e-11, global = 9.1611e-12, cumulative = 4.23392e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.0162736, Final residual = 8.73113e-06, No Iterations 7
# smoothSolver:  Solving for k, Initial residual = 0.0276017, Final residual = 6.32861e-06, No Iterations 9
# ExecutionTime = 0.58 s  ClockTime = 1 s
#
# Courant Number mean: 0.454183 max: 4.89224
# deltaT = 0.000109109
# Time = 0.000834825
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00700358, Final residual = 7.70893e-06, No Iterations 6
# smoothSolver:  Solving for Uy, Initial residual = 0.00774388, Final residual = 5.25991e-06, No Iterations 7
# GAMG:  Solving for p, Initial residual = 0.12715, Final residual = 0.000748626, No Iterations 4
# time step continuity errors : sum local = 5.37753e-07, global = -6.066e-11, cumulative = 4.23331e-07
# GAMG:  Solving for p, Initial residual = 0.0604341, Final residual = 9.52431e-08, No Iterations 16
# time step continuity errors : sum local = 6.75821e-11, global = 1.22425e-11, cumulative = 4.23343e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.0141887, Final residual = 5.30188e-06, No Iterations 7
# smoothSolver:  Solving for k, Initial residual = 0.0251648, Final residual = 9.93828e-06, No Iterations 8
# ExecutionTime = 0.62 s  ClockTime = 1 s
#
# Courant Number mean: 0.465102 max: 4.87178
# deltaT = 0.00011177
# Time = 0.000946595
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00708005, Final residual = 8.26426e-06, No Iterations 6
# smoothSolver:  Solving for Uy, Initial residual = 0.00796454, Final residual = 5.27533e-06, No Iterations 7
# GAMG:  Solving for p, Initial residual = 0.121592, Final residual = 0.000896165, No Iterations 4
# time step continuity errors : sum local = 6.65064e-07, global = 9.99017e-09, cumulative = 4.33334e-07
# GAMG:  Solving for p, Initial residual = 0.0610717, Final residual = 8.43798e-08, No Iterations 17
# time step continuity errors : sum local = 6.20133e-11, global = 1.10225e-11, cumulative = 4.33345e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.013217, Final residual = 9.77408e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0235055, Final residual = 6.99959e-06, No Iterations 8
# ExecutionTime = 0.67 s  ClockTime = 1 s
#
# Courant Number mean: 0.476736 max: 4.87079
# deltaT = 0.0001146
# Time = 0.0010612
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00715393, Final residual = 9.00116e-06, No Iterations 6
# smoothSolver:  Solving for Uy, Initial residual = 0.00826859, Final residual = 5.54993e-06, No Iterations 7
# GAMG:  Solving for p, Initial residual = 0.118018, Final residual = 0.000866796, No Iterations 4
# time step continuity errors : sum local = 6.61835e-07, global = 3.00075e-09, cumulative = 4.36345e-07
# GAMG:  Solving for p, Initial residual = 0.0624861, Final residual = 9.23802e-08, No Iterations 14
# time step continuity errors : sum local = 7.02032e-11, global = -1.14861e-11, cumulative = 4.36334e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.012826, Final residual = 6.60074e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0220643, Final residual = 5.48227e-06, No Iterations 8
# ExecutionTime = 0.71 s  ClockTime = 1 s
#
# Courant Number mean: 0.489142 max: 4.85837
# deltaT = 0.000117616
# Time = 0.00117881
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00725736, Final residual = 4.41374e-06, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.00856041, Final residual = 6.10422e-06, No Iterations 7
# GAMG:  Solving for p, Initial residual = 0.116787, Final residual = 0.000891837, No Iterations 4
# time step continuity errors : sum local = 7.06768e-07, global = 4.9938e-09, cumulative = 4.41328e-07
# GAMG:  Solving for p, Initial residual = 0.0642636, Final residual = 9.82852e-08, No Iterations 15
# time step continuity errors : sum local = 7.77823e-11, global = -1.53686e-11, cumulative = 4.41312e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.0123264, Final residual = 4.75457e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0211033, Final residual = 4.76867e-06, No Iterations 8
# ExecutionTime = 0.75 s  ClockTime = 1 s
#
# Courant Number mean: 0.502407 max: 4.85069
# deltaT = 0.000120838
# Time = 0.00129965
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00735863, Final residual = 5.08002e-06, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.00888496, Final residual = 6.88638e-06, No Iterations 7
# GAMG:  Solving for p, Initial residual = 0.117528, Final residual = 0.000883039, No Iterations 4
# time step continuity errors : sum local = 7.31175e-07, global = 3.41871e-09, cumulative = 4.44731e-07
# GAMG:  Solving for p, Initial residual = 0.0665964, Final residual = 5.82225e-08, No Iterations 16
# time step continuity errors : sum local = 4.82539e-11, global = 6.52627e-12, cumulative = 4.44738e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.0114783, Final residual = 3.75037e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0202015, Final residual = 4.54321e-06, No Iterations 8
# ExecutionTime = 0.8 s  ClockTime = 1 s
#
# Courant Number mean: 0.516601 max: 4.87026
# deltaT = 0.000124291
# Time = 0.00142394
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00746356, Final residual = 5.92638e-06, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.00919418, Final residual = 7.9016e-06, No Iterations 7
# GAMG:  Solving for p, Initial residual = 0.119502, Final residual = 0.000873219, No Iterations 4
# time step continuity errors : sum local = 7.58085e-07, global = 4.20568e-09, cumulative = 4.48943e-07
# GAMG:  Solving for p, Initial residual = 0.0684096, Final residual = 9.04627e-08, No Iterations 15
# time step continuity errors : sum local = 7.87901e-11, global = -1.55686e-11, cumulative = 4.48928e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.0111169, Final residual = 9.12465e-06, No Iterations 5
# smoothSolver:  Solving for k, Initial residual = 0.0194726, Final residual = 4.65147e-06, No Iterations 8
# ExecutionTime = 0.85 s  ClockTime = 1 s
#
# Courant Number mean: 0.531858 max: 4.88188
# deltaT = 0.000128001
# Time = 0.00155194
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00757541, Final residual = 6.95477e-06, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.00951514, Final residual = 9.14398e-06, No Iterations 7
# GAMG:  Solving for p, Initial residual = 0.117865, Final residual = 0.000842202, No Iterations 4
# time step continuity errors : sum local = 7.68615e-07, global = 3.11852e-09, cumulative = 4.52046e-07
# GAMG:  Solving for p, Initial residual = 0.0696874, Final residual = 6.39922e-08, No Iterations 16
# time step continuity errors : sum local = 5.84767e-11, global = 9.54063e-12, cumulative = 4.52056e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.0104382, Final residual = 8.56085e-06, No Iterations 5
# smoothSolver:  Solving for k, Initial residual = 0.0188915, Final residual = 5.01684e-06, No Iterations 8
# ExecutionTime = 0.89 s  ClockTime = 1 s
#
# Courant Number mean: 0.548269 max: 4.90843
# deltaT = 0.00012997
# Time = 0.00168191
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.0075807, Final residual = 7.60115e-06, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.00968597, Final residual = 9.81885e-06, No Iterations 7
# GAMG:  Solving for p, Initial residual = 0.116564, Final residual = 0.000812226, No Iterations 4
# time step continuity errors : sum local = 7.62612e-07, global = 3.49549e-09, cumulative = 4.55551e-07
# GAMG:  Solving for p, Initial residual = 0.0694037, Final residual = 8.58812e-08, No Iterations 16
# time step continuity errors : sum local = 8.08011e-11, global = -1.63723e-11, cumulative = 4.55535e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00986104, Final residual = 8.03616e-06, No Iterations 5
# smoothSolver:  Solving for k, Initial residual = 0.0181661, Final residual = 5.14264e-06, No Iterations 8
# ExecutionTime = 0.94 s  ClockTime = 1 s
#
# Courant Number mean: 0.557299 max: 4.88916
# deltaT = 0.000132033
# Time = 0.00181394
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00758894, Final residual = 8.29088e-06, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.00984596, Final residual = 5.02325e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.114113, Final residual = 0.000800641, No Iterations 4
# time step continuity errors : sum local = 7.71025e-07, global = 2.97883e-09, cumulative = 4.58514e-07
# GAMG:  Solving for p, Initial residual = 0.0692574, Final residual = 7.29361e-08, No Iterations 16
# time step continuity errors : sum local = 7.01368e-11, global = -1.69126e-11, cumulative = 4.58497e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00918544, Final residual = 7.89813e-06, No Iterations 5
# smoothSolver:  Solving for k, Initial residual = 0.0174914, Final residual = 5.36919e-06, No Iterations 8
# ExecutionTime = 0.99 s  ClockTime = 1 s
#
# Courant Number mean: 0.566781 max: 4.86857
# deltaT = 0.000136434
# Time = 0.00195038
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00771658, Final residual = 9.72955e-06, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.0101811, Final residual = 5.89277e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.114404, Final residual = 0.000804336, No Iterations 4
# time step continuity errors : sum local = 8.12351e-07, global = 3.44304e-09, cumulative = 4.6194e-07
# GAMG:  Solving for p, Initial residual = 0.0696918, Final residual = 6.72715e-08, No Iterations 17
# time step continuity errors : sum local = 6.77398e-11, global = 1.0725e-11, cumulative = 4.6195e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00883195, Final residual = 8.51233e-06, No Iterations 5
# smoothSolver:  Solving for k, Initial residual = 0.0172282, Final residual = 6.17502e-06, No Iterations 8
# ExecutionTime = 1.04 s  ClockTime = 1 s
#
# Courant Number mean: 0.586375 max: 4.92891
# deltaT = 0.000138787
# Time = 0.00208916
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00772861, Final residual = 5.26218e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0103448, Final residual = 6.29456e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.111953, Final residual = 0.000824791, No Iterations 4
# time step continuity errors : sum local = 8.52702e-07, global = 3.33521e-09, cumulative = 4.65286e-07
# GAMG:  Solving for p, Initial residual = 0.0692582, Final residual = 7.55484e-08, No Iterations 17
# time step continuity errors : sum local = 7.79654e-11, global = 1.36921e-11, cumulative = 4.65299e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00834617, Final residual = 8.78449e-06, No Iterations 5
# smoothSolver:  Solving for k, Initial residual = 0.0167678, Final residual = 6.52795e-06, No Iterations 8
# ExecutionTime = 1.09 s  ClockTime = 1 s
#
# Courant Number mean: 0.597234 max: 4.94248
# deltaT = 0.000141265
# Time = 0.00223043
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00775126, Final residual = 5.71138e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0105223, Final residual = 6.67603e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.110507, Final residual = 0.000844902, No Iterations 4
# time step continuity errors : sum local = 8.9491e-07, global = 3.48753e-09, cumulative = 4.68787e-07
# GAMG:  Solving for p, Initial residual = 0.0686928, Final residual = 7.46802e-08, No Iterations 17
# time step continuity errors : sum local = 7.89324e-11, global = 1.41741e-11, cumulative = 4.68801e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00801523, Final residual = 9.24126e-06, No Iterations 5
# smoothSolver:  Solving for k, Initial residual = 0.0164029, Final residual = 6.90015e-06, No Iterations 8
# ExecutionTime = 1.13 s  ClockTime = 2 s
#
# Courant Number mean: 0.608726 max: 4.95456
# deltaT = 0.000141265
# Time = 0.00237169
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.0076385, Final residual = 5.62495e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0105175, Final residual = 6.40139e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.107191, Final residual = 0.000867066, No Iterations 4
# time step continuity errors : sum local = 9.17051e-07, global = 8.01748e-10, cumulative = 4.69603e-07
# GAMG:  Solving for p, Initial residual = 0.06695, Final residual = 7.41149e-08, No Iterations 17
# time step continuity errors : sum local = 7.82156e-11, global = 1.41633e-11, cumulative = 4.69617e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00761598, Final residual = 9.08677e-06, No Iterations 5
# smoothSolver:  Solving for k, Initial residual = 0.0158507, Final residual = 6.6205e-06, No Iterations 8
# ExecutionTime = 1.19 s  ClockTime = 2 s
#
# Courant Number mean: 0.609581 max: 4.87839
# deltaT = 0.00014393
# Time = 0.00251563
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00766798, Final residual = 6.02306e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0107114, Final residual = 6.72694e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.105159, Final residual = 0.000887392, No Iterations 4
# time step continuity errors : sum local = 9.6176e-07, global = 1.7582e-09, cumulative = 4.71375e-07
# GAMG:  Solving for p, Initial residual = 0.066382, Final residual = 7.73075e-08, No Iterations 17
# time step continuity errors : sum local = 8.35161e-11, global = 1.53025e-11, cumulative = 4.7139e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00748932, Final residual = 9.66165e-06, No Iterations 5
# smoothSolver:  Solving for k, Initial residual = 0.0156448, Final residual = 6.95687e-06, No Iterations 8
# ExecutionTime = 1.23 s  ClockTime = 2 s
#
# Courant Number mean: 0.621985 max: 4.91812
# deltaT = 0.000146752
# Time = 0.00266238
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00771361, Final residual = 6.42932e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0109257, Final residual = 7.0697e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.103968, Final residual = 0.000931522, No Iterations 4
# time step continuity errors : sum local = 1.03482e-06, global = 1.72287e-09, cumulative = 4.73113e-07
# GAMG:  Solving for p, Initial residual = 0.0661674, Final residual = 8.37221e-08, No Iterations 17
# time step continuity errors : sum local = 9.26582e-11, global = 1.67009e-11, cumulative = 4.7313e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00740973, Final residual = 3.60981e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0155026, Final residual = 7.28642e-06, No Iterations 8
# ExecutionTime = 1.28 s  ClockTime = 2 s
#
# Courant Number mean: 0.635182 max: 4.95498
# deltaT = 0.000146752
# Time = 0.00280913
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00761045, Final residual = 6.18159e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0109335, Final residual = 6.68517e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.102051, Final residual = 0.000945772, No Iterations 4
# time step continuity errors : sum local = 1.04732e-06, global = 1.59562e-09, cumulative = 4.74726e-07
# GAMG:  Solving for p, Initial residual = 0.0651411, Final residual = 9.04048e-08, No Iterations 17
# time step continuity errors : sum local = 9.97346e-11, global = 1.86746e-11, cumulative = 4.74744e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00720422, Final residual = 3.51219e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0151025, Final residual = 6.87084e-06, No Iterations 8
# ExecutionTime = 1.33 s  ClockTime = 2 s
#
# Courant Number mean: 0.63625 max: 4.89357
# deltaT = 0.00014981
# Time = 0.00295894
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00767429, Final residual = 6.56235e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.011172, Final residual = 7.04629e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.100928, Final residual = 0.000997199, No Iterations 4
# time step continuity errors : sum local = 1.1325e-06, global = 2.17262e-09, cumulative = 4.76917e-07
# GAMG:  Solving for p, Initial residual = 0.0651293, Final residual = 8.72701e-08, No Iterations 17
# time step continuity errors : sum local = 9.86224e-11, global = 1.72499e-11, cumulative = 4.76934e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.0071629, Final residual = 3.74941e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0150442, Final residual = 7.1679e-06, No Iterations 8
# ExecutionTime = 1.38 s  ClockTime = 2 s
#
# Courant Number mean: 0.650667 max: 4.95045
# deltaT = 0.00014981
# Time = 0.00310875
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00756757, Final residual = 6.24286e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0111717, Final residual = 6.65928e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.0989755, Final residual = 0.000363044, No Iterations 5
# time step continuity errors : sum local = 4.10396e-07, global = 2.93559e-09, cumulative = 4.7987e-07
# GAMG:  Solving for p, Initial residual = 0.0639061, Final residual = 9.52812e-08, No Iterations 14
# time step continuity errors : sum local = 1.07242e-10, global = -1.39776e-11, cumulative = 4.79856e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00696127, Final residual = 3.62855e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0147112, Final residual = 6.6917e-06, No Iterations 8
# ExecutionTime = 1.42 s  ClockTime = 2 s
#
# Courant Number mean: 0.65186 max: 4.89888
# deltaT = 0.000153139
# Time = 0.00326189
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00761761, Final residual = 6.58487e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0114182, Final residual = 7.08143e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.0989055, Final residual = 0.00042352, No Iterations 5
# time step continuity errors : sum local = 4.91546e-07, global = 5.0454e-09, cumulative = 4.84901e-07
# GAMG:  Solving for p, Initial residual = 0.064183, Final residual = 5.01585e-08, No Iterations 14
# time step continuity errors : sum local = 5.78418e-11, global = 9.31463e-12, cumulative = 4.84911e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.0069015, Final residual = 3.87525e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0147175, Final residual = 6.96506e-06, No Iterations 8
# ExecutionTime = 1.47 s  ClockTime = 2 s
#
# Courant Number mean: 0.667614 max: 4.94831
# deltaT = 0.000153139
# Time = 0.00341503
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00752327, Final residual = 6.23817e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0114219, Final residual = 6.7293e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.0970347, Final residual = 0.000422686, No Iterations 5
# time step continuity errors : sum local = 4.87837e-07, global = 3.77303e-09, cumulative = 4.88684e-07
# GAMG:  Solving for p, Initial residual = 0.0632019, Final residual = 8.89298e-08, No Iterations 14
# time step continuity errors : sum local = 1.02068e-10, global = -1.08553e-11, cumulative = 4.88673e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00670422, Final residual = 3.71652e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0144001, Final residual = 6.45222e-06, No Iterations 8
# ExecutionTime = 1.51 s  ClockTime = 2 s
#
# Courant Number mean: 0.668905 max: 4.90325
# deltaT = 0.000156785
# Time = 0.00357181
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00759964, Final residual = 6.63703e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0116717, Final residual = 7.26543e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.0982793, Final residual = 0.000436293, No Iterations 5
# time step continuity errors : sum local = 5.17455e-07, global = 5.75406e-09, cumulative = 4.94427e-07
# GAMG:  Solving for p, Initial residual = 0.0637934, Final residual = 6.81389e-08, No Iterations 15
# time step continuity errors : sum local = 8.01974e-11, global = 9.93587e-12, cumulative = 4.94437e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00665618, Final residual = 3.95966e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0144298, Final residual = 6.71189e-06, No Iterations 8
# ExecutionTime = 1.56 s  ClockTime = 2 s
#
# Courant Number mean: 0.686214 max: 4.96781
# deltaT = 0.000156785
# Time = 0.0037286
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00749912, Final residual = 6.27189e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0116598, Final residual = 6.94303e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.0960947, Final residual = 0.000448101, No Iterations 5
# time step continuity errors : sum local = 5.27802e-07, global = 6.33555e-09, cumulative = 5.00772e-07
# GAMG:  Solving for p, Initial residual = 0.0631892, Final residual = 7.62856e-08, No Iterations 15
# time step continuity errors : sum local = 8.92732e-11, global = 1.14034e-11, cumulative = 5.00784e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00645977, Final residual = 3.77308e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0141288, Final residual = 6.17347e-06, No Iterations 8
# ExecutionTime = 1.6 s  ClockTime = 2 s
#
# Courant Number mean: 0.687638 max: 4.91222
# deltaT = 0.000160805
# Time = 0.0038894
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.0075795, Final residual = 6.72621e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.011925, Final residual = 7.62187e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.0965906, Final residual = 0.000467072, No Iterations 5
# time step continuity errors : sum local = 5.66164e-07, global = 6.34991e-09, cumulative = 5.07134e-07
# GAMG:  Solving for p, Initial residual = 0.0638393, Final residual = 6.30074e-08, No Iterations 15
# time step continuity errors : sum local = 7.58336e-11, global = 9.15719e-12, cumulative = 5.07143e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00644375, Final residual = 4.03972e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0141884, Final residual = 6.43658e-06, No Iterations 8
# ExecutionTime = 1.65 s  ClockTime = 2 s
#
# Courant Number mean: 0.706773 max: 4.9797
# deltaT = 0.000160805
# Time = 0.00405021
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00747354, Final residual = 6.35113e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0118949, Final residual = 7.31903e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.095218, Final residual = 0.000480592, No Iterations 5
# time step continuity errors : sum local = 5.78863e-07, global = 7.22049e-09, cumulative = 5.14363e-07
# GAMG:  Solving for p, Initial residual = 0.0631649, Final residual = 7.08919e-08, No Iterations 14
# time step continuity errors : sum local = 8.49482e-11, global = -1.02508e-11, cumulative = 5.14353e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00628061, Final residual = 3.8372e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0138932, Final residual = 5.8831e-06, No Iterations 8
# ExecutionTime = 1.69 s  ClockTime = 2 s
#
# Courant Number mean: 0.70827 max: 4.93161
# deltaT = 0.000165272
# Time = 0.00421548
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00756703, Final residual = 6.89164e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0121849, Final residual = 8.15694e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.0955781, Final residual = 0.000503837, No Iterations 5
# time step continuity errors : sum local = 6.26859e-07, global = 6.00414e-09, cumulative = 5.20357e-07
# GAMG:  Solving for p, Initial residual = 0.0636958, Final residual = 9.95062e-08, No Iterations 14
# time step continuity errors : sum local = 1.23015e-10, global = 1.83585e-11, cumulative = 5.20375e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00628527, Final residual = 4.14391e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0139758, Final residual = 6.16724e-06, No Iterations 8
# ExecutionTime = 1.74 s  ClockTime = 2 s
#
# Courant Number mean: 0.729519 max: 5.01423
# deltaT = 0.000165272
# Time = 0.00438075
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00745552, Final residual = 6.51436e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0121383, Final residual = 7.84892e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.0933589, Final residual = 0.000521179, No Iterations 5
# time step continuity errors : sum local = 6.44409e-07, global = 4.87792e-09, cumulative = 5.25253e-07
# GAMG:  Solving for p, Initial residual = 0.0626148, Final residual = 7.22667e-08, No Iterations 15
# time step continuity errors : sum local = 8.89012e-11, global = -1.12614e-11, cumulative = 5.25242e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00612449, Final residual = 3.93383e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0136789, Final residual = 5.61088e-06, No Iterations 8
# ExecutionTime = 1.78 s  ClockTime = 2 s
#
# Courant Number mean: 0.731086 max: 4.95905
# deltaT = 0.000165272
# Time = 0.00454602
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00734226, Final residual = 6.16226e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0120884, Final residual = 7.55358e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.0915042, Final residual = 0.000529768, No Iterations 5
# time step continuity errors : sum local = 6.51411e-07, global = 4.05087e-09, cumulative = 5.29293e-07
# GAMG:  Solving for p, Initial residual = 0.0611526, Final residual = 7.27793e-08, No Iterations 15
# time step continuity errors : sum local = 8.90166e-11, global = -1.16998e-11, cumulative = 5.29281e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00597525, Final residual = 3.74348e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0133886, Final residual = 5.09754e-06, No Iterations 8
# ExecutionTime = 1.83 s  ClockTime = 2 s
#
# Courant Number mean: 0.732644 max: 4.90336
# deltaT = 0.000170437
# Time = 0.00471646
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00745388, Final residual = 6.82326e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0124014, Final residual = 8.58024e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.092643, Final residual = 0.000555496, No Iterations 5
# time step continuity errors : sum local = 7.08525e-07, global = 3.88233e-09, cumulative = 5.33164e-07
# GAMG:  Solving for p, Initial residual = 0.0623524, Final residual = 9.98195e-08, No Iterations 14
# time step continuity errors : sum local = 1.2652e-10, global = 1.57955e-11, cumulative = 5.33179e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00599289, Final residual = 4.121e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0135047, Final residual = 5.4184e-06, No Iterations 8
# ExecutionTime = 1.86 s  ClockTime = 2 s
#
# Courant Number mean: 0.757195 max: 5.00517
# deltaT = 0.000170437
# Time = 0.0048869
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00733944, Final residual = 6.46413e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0123303, Final residual = 8.24057e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.0907861, Final residual = 0.000568983, No Iterations 5
# time step continuity errors : sum local = 7.21287e-07, global = 3.1821e-09, cumulative = 5.36362e-07
# GAMG:  Solving for p, Initial residual = 0.0617254, Final residual = 9.86916e-08, No Iterations 14
# time step continuity errors : sum local = 1.24574e-10, global = -1.07501e-11, cumulative = 5.36351e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00582981, Final residual = 3.92655e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0132019, Final residual = 4.91885e-06, No Iterations 8
# ExecutionTime = 1.9 s  ClockTime = 2 s
#
# Courant Number mean: 0.758842 max: 4.9559
# deltaT = 0.000170437
# Time = 0.00505733
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00722391, Final residual = 6.12515e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0122498, Final residual = 7.89822e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.0886446, Final residual = 0.000571437, No Iterations 5
# time step continuity errors : sum local = 7.20777e-07, global = 3.28247e-09, cumulative = 5.39633e-07
# GAMG:  Solving for p, Initial residual = 0.0603569, Final residual = 6.78429e-08, No Iterations 16
# time step continuity errors : sum local = 8.52469e-11, global = -1.60341e-11, cumulative = 5.39617e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.0056792, Final residual = 3.74711e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0129051, Final residual = 9.21257e-06, No Iterations 7
# ExecutionTime = 1.94 s  ClockTime = 2 s
#
# Courant Number mean: 0.760462 max: 4.90607
# deltaT = 0.000176524
# Time = 0.00523386
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00735819, Final residual = 6.95242e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0125951, Final residual = 9.15668e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.0907911, Final residual = 0.000594699, No Iterations 5
# time step continuity errors : sum local = 7.83417e-07, global = 3.78054e-09, cumulative = 5.43398e-07
# GAMG:  Solving for p, Initial residual = 0.0617388, Final residual = 9.90814e-08, No Iterations 16
# time step continuity errors : sum local = 1.29883e-10, global = -2.33538e-11, cumulative = 5.43374e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00571568, Final residual = 4.22095e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0130566, Final residual = 9.98566e-06, No Iterations 7
# ExecutionTime = 1.98 s  ClockTime = 2 s
#
# Courant Number mean: 0.789316 max: 5.02653
# deltaT = 0.000176524
# Time = 0.00541038
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00724069, Final residual = 6.59832e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0124957, Final residual = 8.76598e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.0888475, Final residual = 0.000606008, No Iterations 5
# time step continuity errors : sum local = 7.94235e-07, global = 3.51777e-09, cumulative = 5.46892e-07
# GAMG:  Solving for p, Initial residual = 0.0609366, Final residual = 6.19695e-08, No Iterations 17
# time step continuity errors : sum local = 8.09545e-11, global = 1.44089e-11, cumulative = 5.46907e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00556642, Final residual = 4.02865e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0127463, Final residual = 9.17252e-06, No Iterations 7
# ExecutionTime = 2.02 s  ClockTime = 2 s
#
# Courant Number mean: 0.790967 max: 4.9723
# deltaT = 0.000176524
# Time = 0.00558691
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00712167, Final residual = 6.26016e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0123855, Final residual = 8.37491e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.0866345, Final residual = 0.000605712, No Iterations 5
# time step continuity errors : sum local = 7.90536e-07, global = 4.04517e-09, cumulative = 5.50952e-07
# GAMG:  Solving for p, Initial residual = 0.0593519, Final residual = 8.3109e-08, No Iterations 15
# time step continuity errors : sum local = 1.08111e-10, global = -7.93171e-12, cumulative = 5.50944e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00542581, Final residual = 3.85024e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0124434, Final residual = 8.44019e-06, No Iterations 7
# ExecutionTime = 2.06 s  ClockTime = 3 s
#
# Courant Number mean: 0.792584 max: 4.9258
# deltaT = 0.000176524
# Time = 0.00576343
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00700344, Final residual = 5.9421e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0122754, Final residual = 7.99163e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.0846642, Final residual = 0.000607023, No Iterations 5
# time step continuity errors : sum local = 7.88809e-07, global = 4.36714e-09, cumulative = 5.55311e-07
# GAMG:  Solving for p, Initial residual = 0.0582103, Final residual = 8.06849e-08, No Iterations 17
# time step continuity errors : sum local = 1.04509e-10, global = -1.96308e-11, cumulative = 5.55291e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00529386, Final residual = 9.90177e-06, No Iterations 5
# smoothSolver:  Solving for k, Initial residual = 0.0121497, Final residual = 7.78272e-06, No Iterations 7
# ExecutionTime = 2.09 s  ClockTime = 3 s
#
# Courant Number mean: 0.794168 max: 4.88095
# deltaT = 0.000184199
# Time = 0.00594763
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00718109, Final residual = 7.01857e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0126813, Final residual = 9.62129e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.0876669, Final residual = 0.000634778, No Iterations 5
# time step continuity errors : sum local = 8.70337e-07, global = 5.47791e-09, cumulative = 5.60769e-07
# GAMG:  Solving for p, Initial residual = 0.0602382, Final residual = 8.06024e-08, No Iterations 18
# time step continuity errors : sum local = 1.09992e-10, global = 2.2473e-11, cumulative = 5.60792e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00538108, Final residual = 4.32569e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0123723, Final residual = 8.83631e-06, No Iterations 7
# ExecutionTime = 2.13 s  ClockTime = 3 s
#
# Courant Number mean: 0.830405 max: 5.04233
# deltaT = 0.000184199
# Time = 0.00613183
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.0070579, Final residual = 6.65884e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0125498, Final residual = 9.16219e-06, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.0861033, Final residual = 0.000644486, No Iterations 5
# time step continuity errors : sum local = 8.78802e-07, global = 5.14895e-09, cumulative = 5.65941e-07
# GAMG:  Solving for p, Initial residual = 0.0598989, Final residual = 8.41972e-08, No Iterations 18
# time step continuity errors : sum local = 1.1452e-10, global = 2.45578e-11, cumulative = 5.65965e-07
# smoothSolver:  Solving for epsilon, Initial residual = 0.00525036, Final residual = 4.13314e-06, No Iterations 6
# smoothSolver:  Solving for k, Initial residual = 0.0120762, Final residual = 8.19531e-06, No Iterations 7
# ExecutionTime = 2.17 s  ClockTime = 3 s
#
# Courant Number mean: 0.832085 max: 4.9919
# deltaT = 0.000184199
# Time = 0.00631603
#
# PIMPLE: iteration 1
# ...
# Time = 0.0335897
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00379415, Final residual = 6.95145e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0100533, Final residual = 9.57399e-06, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0412205, Final residual = 0.000169019, No Iterations 5
# time step continuity errors : sum local = 2.76703e-07, global = 7.49575e-09, cumulative = 1.49497e-06
# GAMG:  Solving for p, Initial residual = 0.029102, Final residual = 7.75929e-08, No Iterations 16
# time step continuity errors : sum local = 1.27163e-10, global = -2.54123e-11, cumulative = 1.49495e-06
# smoothSolver:  Solving for epsilon, Initial residual = 0.0030263, Final residual = 6.37739e-06, No Iterations 7
# smoothSolver:  Solving for k, Initial residual = 0.0044352, Final residual = 7.97096e-06, No Iterations 9
# ExecutionTime = 8.66 s  ClockTime = 10 s
#
# Courant Number mean: 1.25479 max: 4.9919
# deltaT = 0.00025641
# Time = 0.0338462
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00379638, Final residual = 6.99977e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0100919, Final residual = 9.6657e-06, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0412349, Final residual = 0.000167663, No Iterations 5
# time step continuity errors : sum local = 2.74157e-07, global = 7.25402e-09, cumulative = 1.5022e-06
# GAMG:  Solving for p, Initial residual = 0.0291191, Final residual = 7.71093e-08, No Iterations 16
# time step continuity errors : sum local = 1.26028e-10, global = -2.53915e-11, cumulative = 1.50218e-06
# smoothSolver:  Solving for epsilon, Initial residual = 0.00303296, Final residual = 6.44122e-06, No Iterations 7
# smoothSolver:  Solving for k, Initial residual = 0.00443333, Final residual = 7.99814e-06, No Iterations 9
# ExecutionTime = 8.71 s  ClockTime = 10 s
#
# Courant Number mean: 1.25456 max: 4.99127
# deltaT = 0.00025641
# Time = 0.0341026
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00379905, Final residual = 7.04504e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0101285, Final residual = 9.75349e-06, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0411714, Final residual = 0.000166437, No Iterations 5
# time step continuity errors : sum local = 2.71779e-07, global = 7.047e-09, cumulative = 1.50922e-06
# GAMG:  Solving for p, Initial residual = 0.0291106, Final residual = 7.73348e-08, No Iterations 16
# time step continuity errors : sum local = 1.26047e-10, global = -2.55237e-11, cumulative = 1.5092e-06
# smoothSolver:  Solving for epsilon, Initial residual = 0.00303962, Final residual = 6.50161e-06, No Iterations 7
# smoothSolver:  Solving for k, Initial residual = 0.00443137, Final residual = 8.02208e-06, No Iterations 9
# ExecutionTime = 8.76 s  ClockTime = 10 s
#
# Courant Number mean: 1.25432 max: 4.99064
# deltaT = 0.00025641
# Time = 0.034359
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00380147, Final residual = 7.08912e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0101669, Final residual = 9.838e-06, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0411094, Final residual = 0.000410866, No Iterations 4
# time step continuity errors : sum local = 6.70084e-07, global = 9.71693e-09, cumulative = 1.51892e-06
# GAMG:  Solving for p, Initial residual = 0.029021, Final residual = 6.11181e-08, No Iterations 16
# time step continuity errors : sum local = 9.93801e-11, global = -2.00844e-11, cumulative = 1.5189e-06
# smoothSolver:  Solving for epsilon, Initial residual = 0.00304577, Final residual = 6.55829e-06, No Iterations 7
# smoothSolver:  Solving for k, Initial residual = 0.00442928, Final residual = 8.04301e-06, No Iterations 9
# ExecutionTime = 8.81 s  ClockTime = 11 s
#
# Courant Number mean: 1.25406 max: 4.99002
# deltaT = 0.00025641
# Time = 0.0346154
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00380086, Final residual = 7.08895e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0102045, Final residual = 9.92826e-06, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0409268, Final residual = 0.00038564, No Iterations 4
# time step continuity errors : sum local = 6.28066e-07, global = 1.46113e-08, cumulative = 1.53351e-06
# GAMG:  Solving for p, Initial residual = 0.0289979, Final residual = 7.97204e-08, No Iterations 16
# time step continuity errors : sum local = 1.29223e-10, global = 2.36497e-11, cumulative = 1.53353e-06
# smoothSolver:  Solving for epsilon, Initial residual = 0.0030513, Final residual = 6.61191e-06, No Iterations 7
# smoothSolver:  Solving for k, Initial residual = 0.00442721, Final residual = 8.0615e-06, No Iterations 9
# ExecutionTime = 8.85 s  ClockTime = 11 s
#
# Courant Number mean: 1.2538 max: 4.9894
# deltaT = 0.00025641
# Time = 0.0348718
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00380408, Final residual = 7.14412e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0102423, Final residual = 5.63139e-06, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0409323, Final residual = 0.000390806, No Iterations 4
# time step continuity errors : sum local = 6.35957e-07, global = 6.90277e-09, cumulative = 1.54043e-06
# GAMG:  Solving for p, Initial residual = 0.0289711, Final residual = 6.01344e-08, No Iterations 16
# time step continuity errors : sum local = 9.72905e-11, global = 1.87675e-11, cumulative = 1.54045e-06
# smoothSolver:  Solving for epsilon, Initial residual = 0.00305676, Final residual = 6.66282e-06, No Iterations 7
# smoothSolver:  Solving for k, Initial residual = 0.00442511, Final residual = 8.07764e-06, No Iterations 9
# ExecutionTime = 8.9 s  ClockTime = 11 s
#
# Courant Number mean: 1.25351 max: 4.98879
# deltaT = 0.00025641
# Time = 0.0351282
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00380667, Final residual = 7.16978e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0102776, Final residual = 5.67819e-06, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0408545, Final residual = 0.000380269, No Iterations 4
# time step continuity errors : sum local = 6.17638e-07, global = 1.61815e-08, cumulative = 1.55663e-06
# GAMG:  Solving for p, Initial residual = 0.0289426, Final residual = 8.03877e-08, No Iterations 16
# time step continuity errors : sum local = 1.29745e-10, global = 2.16344e-11, cumulative = 1.55666e-06
# smoothSolver:  Solving for epsilon, Initial residual = 0.00306225, Final residual = 6.71096e-06, No Iterations 7
# smoothSolver:  Solving for k, Initial residual = 0.00442332, Final residual = 8.09189e-06, No Iterations 9
# ExecutionTime = 8.95 s  ClockTime = 11 s
#
# Courant Number mean: 1.25322 max: 4.98818
# deltaT = 0.00025641
# Time = 0.0353846
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00380933, Final residual = 7.21882e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0103177, Final residual = 5.72123e-06, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.040841, Final residual = 0.000387229, No Iterations 4
# time step continuity errors : sum local = 6.28499e-07, global = 5.9858e-09, cumulative = 1.56264e-06
# GAMG:  Solving for p, Initial residual = 0.0289196, Final residual = 7.69163e-08, No Iterations 16
# time step continuity errors : sum local = 1.23911e-10, global = 2.22102e-11, cumulative = 1.56266e-06
# smoothSolver:  Solving for epsilon, Initial residual = 0.00306699, Final residual = 6.75752e-06, No Iterations 7
# smoothSolver:  Solving for k, Initial residual = 0.00442123, Final residual = 8.10455e-06, No Iterations 9
# ExecutionTime = 9 s  ClockTime = 11 s
#
# Courant Number mean: 1.25291 max: 4.98758
# deltaT = 0.00025641
# Time = 0.035641
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00381298, Final residual = 7.24058e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0103548, Final residual = 5.76723e-06, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0407645, Final residual = 0.000376149, No Iterations 4
# time step continuity errors : sum local = 6.09273e-07, global = 1.29485e-08, cumulative = 1.57561e-06
# GAMG:  Solving for p, Initial residual = 0.0288528, Final residual = 7.7124e-08, No Iterations 16
# time step continuity errors : sum local = 1.2403e-10, global = 1.98169e-11, cumulative = 1.57563e-06
# smoothSolver:  Solving for epsilon, Initial residual = 0.00307152, Final residual = 6.80229e-06, No Iterations 7
# smoothSolver:  Solving for k, Initial residual = 0.00441911, Final residual = 8.11615e-06, No Iterations 9
# ExecutionTime = 9.05 s  ClockTime = 11 s
#
# Courant Number mean: 1.25259 max: 4.98893
# deltaT = 0.00025641
# Time = 0.0358974
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00381641, Final residual = 7.28483e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0103945, Final residual = 5.80808e-06, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0407097, Final residual = 0.0003832, No Iterations 4
# time step continuity errors : sum local = 6.20241e-07, global = 5.86068e-09, cumulative = 1.58149e-06
# GAMG:  Solving for p, Initial residual = 0.0288216, Final residual = 7.34402e-08, No Iterations 16
# time step continuity errors : sum local = 1.17889e-10, global = 1.88526e-11, cumulative = 1.58151e-06
# smoothSolver:  Solving for epsilon, Initial residual = 0.00307619, Final residual = 6.84524e-06, No Iterations 7
# smoothSolver:  Solving for k, Initial residual = 0.00441723, Final residual = 8.12703e-06, No Iterations 9
# ExecutionTime = 9.1 s  ClockTime = 11 s
#
# Courant Number mean: 1.25226 max: 4.99098
# deltaT = 0.00025641
# Time = 0.0361538
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00382022, Final residual = 7.30299e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.010433, Final residual = 5.85139e-06, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0406473, Final residual = 0.000372852, No Iterations 4
# time step continuity errors : sum local = 6.02219e-07, global = 1.34549e-08, cumulative = 1.59497e-06
# GAMG:  Solving for p, Initial residual = 0.0287504, Final residual = 8.77121e-08, No Iterations 16
# time step continuity errors : sum local = 1.4062e-10, global = 2.22037e-11, cumulative = 1.59499e-06
# smoothSolver:  Solving for epsilon, Initial residual = 0.00308077, Final residual = 6.88727e-06, No Iterations 7
# smoothSolver:  Solving for k, Initial residual = 0.00441522, Final residual = 8.13769e-06, No Iterations 9
# ExecutionTime = 9.15 s  ClockTime = 11 s
#
# Courant Number mean: 1.2519 max: 4.99301
# deltaT = 0.00025641
# Time = 0.0364103
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00382361, Final residual = 7.34075e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0104734, Final residual = 5.8908e-06, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0406103, Final residual = 0.000378716, No Iterations 4
# time step continuity errors : sum local = 6.11164e-07, global = 5.79483e-09, cumulative = 1.60078e-06
# GAMG:  Solving for p, Initial residual = 0.0287001, Final residual = 8.50335e-08, No Iterations 16
# time step continuity errors : sum local = 1.36077e-10, global = 2.16565e-11, cumulative = 1.60081e-06
# smoothSolver:  Solving for epsilon, Initial residual = 0.00308487, Final residual = 6.92854e-06, No Iterations 7
# smoothSolver:  Solving for k, Initial residual = 0.00441347, Final residual = 8.14843e-06, No Iterations 9
# ExecutionTime = 9.19 s  ClockTime = 11 s
#
# Courant Number mean: 1.25155 max: 4.99499
# deltaT = 0.00025641
# Time = 0.0366667
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00382755, Final residual = 7.35666e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.010512, Final residual = 5.93155e-06, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0405343, Final residual = 0.000367463, No Iterations 4
# time step continuity errors : sum local = 5.91819e-07, global = 1.19282e-08, cumulative = 1.61273e-06
# GAMG:  Solving for p, Initial residual = 0.0286131, Final residual = 9.83597e-08, No Iterations 16
# time step continuity errors : sum local = 1.57252e-10, global = 2.62353e-11, cumulative = 1.61276e-06
# smoothSolver:  Solving for epsilon, Initial residual = 0.00308914, Final residual = 6.96874e-06, No Iterations 7
# smoothSolver:  Solving for k, Initial residual = 0.0044118, Final residual = 8.15951e-06, No Iterations 9
# ExecutionTime = 9.24 s  ClockTime = 11 s
#
# Courant Number mean: 1.25117 max: 4.99693
# deltaT = 0.00025641
# Time = 0.0369231
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00383084, Final residual = 7.3874e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0105529, Final residual = 5.96929e-06, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.040474, Final residual = 0.000371975, No Iterations 4
# time step continuity errors : sum local = 5.98529e-07, global = 5.53984e-09, cumulative = 1.6183e-06
# GAMG:  Solving for p, Initial residual = 0.0285639, Final residual = 9.86267e-08, No Iterations 16
# time step continuity errors : sum local = 1.57421e-10, global = 2.69642e-11, cumulative = 1.61833e-06
# smoothSolver:  Solving for epsilon, Initial residual = 0.00309343, Final residual = 7.00851e-06, No Iterations 7
# smoothSolver:  Solving for k, Initial residual = 0.00441034, Final residual = 8.1714e-06, No Iterations 9
# ExecutionTime = 9.29 s  ClockTime = 11 s
#
# Courant Number mean: 1.25078 max: 4.99884
# deltaT = 0.00025641
# Time = 0.0371795
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00383458, Final residual = 7.40088e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0105928, Final residual = 6.00776e-06, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.040392, Final residual = 0.000360777, No Iterations 4
# time step continuity errors : sum local = 5.79428e-07, global = 9.92724e-09, cumulative = 1.62825e-06
# GAMG:  Solving for p, Initial residual = 0.0284586, Final residual = 6.83204e-08, No Iterations 17
# time step continuity errors : sum local = 1.08969e-10, global = -2.25921e-11, cumulative = 1.62823e-06
# smoothSolver:  Solving for epsilon, Initial residual = 0.00309763, Final residual = 7.04779e-06, No Iterations 7
# smoothSolver:  Solving for k, Initial residual = 0.00440913, Final residual = 8.18415e-06, No Iterations 9
# ExecutionTime = 9.37 s  ClockTime = 11 s
#
# Courant Number mean: 1.25039 max: 5.00072
# deltaT = 0.00025641
# Time = 0.0374359
#
# PIMPLE: iteration 1
# smoothSolver:  Solving for Ux, Initial residual = 0.00383764, Final residual = 7.42412e-06, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0106338, Final residual = 6.04395e-06, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0403568, Final residual = 0.000366328, No Iterations 4
# time step continuity errors : sum local = 5.87709e-07, global = 2.607e-09, cumulative = 1.63084e-06
# Terminated
# {'lines': 2648,
#  'uniqueid': '6ae7dc50-8ab4-11ef-8ac0-00155d1ba1b9',
#  'logfile': 'pitzDaily_run/PyFoam.pimpleFoam.logfile',
#  'casefullname': '/mnt/c/work/OpenFOAM/20240906_gijyutusyo/003_PyFoam/pitzDaily_run',
#  'casename': 'pitzDaily_run',
#  'solver': 'pimpleFoam',
#  'solverFull': 'pimpleFoam',
#  'commandLine': 'pimpleFoam -case pitzDaily_run',
#  'hostname': 'JPN118658-M',
#  'remark': 'No remark given',
#  'starttime': 'Tue Oct 15 14:14:56 2024',
#  'time': 0.0374359,
#  'stepNr': 173,
#  'lasttimesteptime': 'Tue Oct 15 14:15:07 2024',
#  'keyboardInterrupt': False,
#  'interrupted': False,
#  'OK': True,
#  'endSeen': False,
#  'cpuTime': 9.598022000000014,
#  'cpuUserTime': 9.276899000000014,
#  'cpuSystemTime': 0.32112300000000005,
#  'wallTime': 11.326261043548584,
#  'usedMemory': 190.7724609375,
#  'endtime': 'Tue Oct 15 14:15:07 2024',
#  'fatalError': False,
#  'fatalFPE': False,
#  'fatalStackdump': False}

# %%
# コピー先のディレクトリ
case_dir = 'pitzDaily_run'

# Allrunをバックグラウンドで実行し、ログを非表示にする
def run_allrun(case_dir):
    with open(os.devnull, 'w') as devnull:
        subprocess.run([f'{os.getcwd()}/{case_dir}/Allrun'], cwd=case_dir, stdout=devnull, stderr=devnull)

# Allrunを実行
run_allrun(case_dir)

# %% [markdown]
# # 計算バックグラウンド

# %%
path.join(getcwd(), case_dir)
# Out:
# '/mnt/c/work/OpenFOAM/20240906_gijyutusyo/003_PyFoam/pitzDaily_runBackground'

# %%
import subprocess
import os
import shutil
import threading
from PyFoam.RunDictionary.SolutionDirectory import SolutionDirectory

# コピー先のディレクトリ
case_dir = 'pitzDaily_runBackground'

# チュートリアルケースをコピー
template.cloneCase(path.join(getcwd(), case_dir))

# Allrunをバックグラウンドで実行し、ログを非表示にする
def run_allrun(case_dir):
    # blockMeshの実行
    block_mesh_runner = BasicRunner(argv=["blockMesh", "-case", case_dir], silent=True, logname= "blockMesh")
    block_mesh_runner.start()

    # pimpleFoamの実行
    pimpleFoam_runner = BasicRunner(argv=["pimpleFoam", "-case", case_dir], silent=True, logname="pimpleFoam")
    pimpleFoam_runner.start()

# スレッドを作成してAllrunをバックグラウンドで実行
allrun_thread = threading.Thread(target=run_allrun, args=(case_dir,))
allrun_thread.start()

# 他の操作を続ける
print("Allrunをバックグラウンドで実行中...")

# 必要に応じてスレッドの終了を待つ
# allrun_thread.join()
# Out:
# Allrunをバックグラウンドで実行中...

# %%
print("test")
# Out:
# test

# %%
# !cat pitzDaily_run/Allrun
# Out:
# #!/bin/bash
#
# # Clean the case
# foamCleanTutorials
#
# # Generate the mesh
# blockMesh
#
# # Run the solver
# pimpleFoam
#
# # Post-processing (optional)
# # e.g., reconstructPar, foamToVTK, etc.
#
# # Notify the user
# echo "Simulation completed."

# %%
import subprocess
import os
import shutil
import threading
from PyFoam.RunDictionary.SolutionDirectory import SolutionDirectory

# コピー先のディレクトリ
case_dir = 'pitzDaily_runBackground'

# 結果を表示
print(template)

# Allrunをバックグラウンドで実行し、ログを非表示にする
def run_allrun(case_dir):
    with open(os.devnull, 'w') as devnull:
        subprocess.run([f'{os.getcwd()}/{case_dir}/Allrun'], cwd=case_dir, stdout=devnull, stderr=devnull)

# スレッドを作成してAllrunをバックグラウンドで実行
allrun_thread = threading.Thread(target=run_allrun, args=(destination,))
allrun_thread.start()

# 他の操作を続ける
print("Allrunをバックグラウンドで実行中...")

# 必要に応じてスレッドの終了を待つ
# allrun_thread.join()
# Out:
# <PyFoam.RunDictionary.SolutionDirectory.SolutionDirectory object at 0x7fd758b526d0>
# Allrunをバックグラウンドで実行中...

# %%
print("test")
# Out:
# test
